# %% [markdown]
# # Seeklight data processing
# - Form training data from the preprocessor

# %%
# edit these fields accordingly
# dataset name
dataset_name = "isleevy" # options = "isleevy",

# %%
# these should stay the same
csv_path = rf"../data/isleevy/original_data/{dataset_name} metadata.csv"
description_col = "Description"
confidence_col = "Description Confidence"
transcript_col = "Transcript"

# %%
import importlib.util
import pandas as pd

# Load helper module
spec = importlib.util.spec_from_file_location("sh", "01-seeklight-training-data-helper.py")
sh = importlib.util.module_from_spec(spec)
spec.loader.exec_module(sh)

# %%
csv_file_rl = pd.read_csv(csv_path)

# Generate training data from processed split data
training_path = sh.format_training_data(
    csv_input_file_path=str(csv_path),
    dataset_name=dataset_name,
    description_col=description_col,
    confidence_col=confidence_col,
    transcript_col=transcript_col
)
# Out:
# Wrote descriptions_included: ../data/isleevy/training/D_isl_descriptions_included.csv
# Wrote transcripts: ../data/isleevy/training/D_isl_transcripts.csv
# Rows: 27
