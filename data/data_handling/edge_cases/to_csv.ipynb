# %% [markdown]
# # To CSV

# %%
import pandas as pd
import csv

# %%
# input/output
input = r'../data/eaadams/EAAdamsCDM metadata.xlsx'
output = r'../data/eaadams/EAAdamsCDM metadata.csv'

def save_csv(df, title):
    df.to_csv(title,
          index=False,
          encoding='utf-8',
          quoting=csv.QUOTE_NONNUMERIC,   
          escapechar='\\',
          lineterminator='\n')

# %%
df = pd.read_excel(input)

save_csv(df, output)

# %%
display(df)
# Out:
#                                                   Title  \
# 0     Letter, 1954 January 17, W.L. Foxworth Sr. to ...
# 1     Postcard, 1954 January 20, President M. Citron...
# 2     Flyer, no date, announcing the hiring of a ger...
# 3     Letter, 1954 January 28, Rev. H.R. Hughes to A...
# 4     Letter, 1954 February 10, Rembert Stokes of Pa...
# ...                                                 ...
# 1759  List, 1961, A Social Action Creed for the Afri...
# 1760  Card, 1962 February 12, Allen University Ninet...
# 1761  Flier, 1962 February 26, The Allen University ...
# 1762  Letter, 1962 March 13, A. D. Green of Allen Un...
# 1763  Eugene Avery Adams papers, 1892-1968, folder 8...
#
#                                      Creator  Contributors    Extent  \
# 0                                        NaN           NaN    1 item
# 1                                        NaN           NaN    1 item
# 2                                        NaN           NaN    1 item
# ...
