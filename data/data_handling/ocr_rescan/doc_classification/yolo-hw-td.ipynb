# %% [markdown]
# # Document Classification

# %%
from ultralytics import YOLO
from huggingface_hub import hf_hub_download
from matplotlib import pyplot as plt

dir_path = "/Users/sdindl/Documents/p17173coll38/"
file = "968.jpg"
path = dir_path + file

# Load the weights from our repository
model_path = hf_hub_download(local_dir=".",
                             repo_id="armvectores/yolov8n_handwritten_text_detection",
                             filename="best.pt")
model = YOLO(model_path)

# # Load test blank
# test_blank_path = hf_hub_download(local_dir=".",
#                              repo_id="armvectores/yolov8n_handwritten_text_detection",
#                              filename=file)

# Do the predictions
res = model.predict(source=path, project='.',name='detected', exist_ok=True, save=True, show=False, show_labels=False, show_conf=False, conf=0.5, )

# plt.figure(figsize=(15,10))
# plt.imshow(plt.imread(f'detected/{file}))
# plt.show()
# Out:
# image 1/1 /Users/sdindl/Documents/p17173coll38/968.jpg: 640x512 (no detections), 35.9ms
# Speed: 2.8ms preprocess, 35.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to /Users/sdindl/Code/AspireAI_LLM_Project/ocr_rescan/doc_classification/detected

# %%
from ultralytics import YOLO
from huggingface_hub import hf_hub_download
from matplotlib import pyplot as plt

# Load the weights from our repository
model_path = hf_hub_download(local_dir=".",
                             repo_id="armvectores/yolov8n_handwritten_text_detection",
                             filename="best.pt")
model = YOLO(model_path)

# Load test blank
test_blank_path = hf_hub_download(local_dir=".",
                             repo_id="armvectores/yolov8n_handwritten_text_detection",
                             filename="test_blank.png")

# Do the predictions
res = model.predict(source=test_blank_path, project='.',name='detected', exist_ok=True, save=True, show=False, show_labels=False, show_conf=False, conf=0.5, )

# plt.figure(figsize=(15,10))
# plt.imshow(plt.imread('detected/test_blank.png'))
# plt.show()
# Out:
# image 1/1 /Users/sdindl/Code/AspireAI_LLM_Project/ocr_rescan/doc_classification/test_blank.png: 640x512 142 words, 40.5ms
# Speed: 2.0ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to /Users/sdindl/Code/AspireAI_LLM_Project/ocr_rescan/doc_classification/detected
