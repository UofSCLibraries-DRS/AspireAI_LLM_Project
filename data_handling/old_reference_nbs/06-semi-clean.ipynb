# %% [markdown]
# # Removal of Messy Chars for transcript tasking

# %%
import pandas as pd
import re
from utils.constants import Paths
from utils.ocr_cleaning import OCR_Clean

# %%
df = pd.read_excel(Paths.mccray_folder + r'changed_data/decade_subsets/McCray (1940s, any_messy = True).xlsx')
df
# Out:
#       Unnamed: 0                                              Title  \
# 0            720  Certificate that Mr. Henry Smith is a member o...
# 1            735  The Lighthouse and Informer paper notes, Octob...
# 2            736  The Lighthouse and Informer paper notes, Octob...
# 3            737  The Lighthouse and Informer paper notes, Febru...
# 4            738  The Lighthouse and Informer paper notes, Febru...
# ...          ...                                                ...
# 3379       14138  Letter from Mildred Chestnut, Secretary at the...
# 3380       14140  Letter from Mildred Chestnut, Secretary at the...
# 3381       14142  Letter from John H. McCray to Dr. E. J. Cling,...
# 3382       14143  Letter from Mrs. E.M. Parker to Mildred Chestn...
# 3383       14144  List of Charleston's Advertising accounts for ...
#
#                                                 Creator  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3379  Chestnut, Mildred (Secretary for Lighthouse an...
# 3380  Chestnut, Mildred (Secretary for Lighthouse an...
# 3381                      McCray, John Henry, 1910-1987
# 3382                      McCray, John Henry, 1910-1987
# 3383                                                NaN
#
#                        Contributors                 Date  Approximate Date  \
# 0     McCray, John Henry, 1910-1987       February, 1942               NaN
# 1     McCray, John Henry, 1910-1987  1941-10-19 00:00:00               NaN
# 2     McCray, John Henry, 1910-1987  1941-10-19 00:00:00               NaN
# 3     McCray, John Henry, 1910-1987  1944-02-06 00:00:00               NaN
# 4     McCray, John Henry, 1910-1987  1944-02-06 00:00:00               NaN
# ...                             ...                  ...               ...
# 3379  McCray, John Henry, 1910-1987  1946-09-25 00:00:00               NaN
# 3380  McCray, John Henry, 1910-1987  1946-09-27 00:00:00               NaN
# 3381  McCray, John Henry, 1910-1987  1946-09-28 00:00:00               NaN
# 3382  McCray, John Henry, 1910-1987  1946-09-30 00:00:00               NaN
# 3383  McCray, John Henry, 1910-1987              1946-08               NaN
#
#                              Source                    Subject Local Subject  \
# 0     Manuscripts; Accession 11294.                      NAACP           NaN
# 1     Manuscripts; Accession 11294.  The Lighthouse & Informer           NaN
# 2     Manuscripts; Accession 11294.  The Lighthouse & Informer           NaN
# 3     Manuscripts; Accession 11294.  The Lighthouse & Informer           NaN
# 4     Manuscripts; Accession 11294.  The Lighthouse & Informer           NaN
# ...                             ...                        ...           ...
# 3379  Manuscripts; Accession 11294.    Lighthouse and Informer           NaN
# 3380  Manuscripts; Accession 11294.    Lighthouse and Informer           NaN
# 3381  Manuscripts; Accession 11294.    Lighthouse and Informer           NaN
# 3382  Manuscripts; Accession 11294.    Lighthouse and Informer           NaN
# 3383  Manuscripts; Accession 11294.    Lighthouse and Informer           NaN
#
#      S.C. County  ... has_messy total_messy_chars  \
# 0            NaN  ...      True                70
# 1            NaN  ...      True                65
# 2            NaN  ...      True                89
# 3            NaN  ...      True               107
# 4            NaN  ...      True               153
# ...          ...  ...       ...               ...
# 3379         NaN  ...      True                 5
# 3380         NaN  ...     False                 0
# 3381         NaN  ...      True                 5
# 3382         NaN  ...     False                 0
# 3383         NaN  ...     False                 0
#
#                                 special_messy_sequences special_messy_count  \
# 0     ['ΓÇó$', '%\\', '^^*^^^', '^^^', '^^', '^┬╗', ...                   7
# 1                ['┬ú', '^^', '┬ú', '&*~', '┬ú', '┬ú*']                   6
# 2             ['┬ú&', '┬ú', '^^', '^^^^^', '^^', '&^&']                   6
# 3              ['^~', '┬░', '^^', '&┬ú#', 'Γûá', 'Γûá']                   6
# 4          ['Γûá', '^*^', '^&', '┬ú', '~=', '┬ú', '┬ú']                   7
# ...                                                 ...                 ...
# 3379                                      ['┬░', '┬«*']                   2
# 3380                                             ['┬Ñ']                   1
# 3381                   ['┬ú&ΓÇó', '┬úΓÇó', 'ΓÇó', '┬½']                   4
# 3382                                            ['ΓÇÖ']                   1
# 3383                              ['ΓÇÖ', 'ΓÇÖ', 'ΓÇÖ']                   3
#
#      has_special_messy total_special_messy_chars repeat_sequences  \
# 0                 True                        25            ['l']
# 1                 True                        14            ['j']
# 2                 True                        17               []
# 3                 True                        16               []
# 4                 True                        16               []
# ...                ...                       ...              ...
# 3379              True                         5               []
# 3380              True                         2               []
# 3381              True                        16               []
# 3382              True                         3               []
# 3383              True                         9               []
#
#      repeat_sequence_count has_repeat_sequence any_messy
# 0                        1                True      True
# 1                        1                True      True
# 2                        0               False      True
# 3                        0               False      True
# 4                        0               False      True
# ...                    ...                 ...       ...
# 3379                     0               False      True
# 3380                     0               False      True
# 3381                     0               False      True
# 3382                     0               False      True
# 3383                     0               False      True
#
# [3384 rows x 48 columns]

# %%
# Special pattern removal
df['semiclean'] = df['Transcript'].apply(lambda x: re.sub(OCR_Clean.special_pattern, "", x))

# %%
# General pattern removal
df['semiclean'] = df['semiclean'].apply(lambda x: re.sub(OCR_Clean.general_pattern, "", x))

# %%
# Repeated char condenser
df['semiclean'] = df['semiclean'].apply(lambda x: re.sub(OCR_Clean.letter_pattern, r'\1', x))

# %%
# Remove other unclean

# Regex pattern for this:
# To remove ^ and ^shortphrases, and remove standalone punctuation not attached to words/numbers.

# \^(\w{0,4})   matches ^ followed by 0–4 word characters (short phrases like ^a, ^ok, ^xyz, ,^fele or just ^)
# |             OR
# (?<!\w)       negative lookbehind: ensures the char before is NOT a word character
# [^\w\s]       matches any single character that is NOT a word char and NOT whitespace (i.e., punctuation)
# (?!\w)        negative lookahead: ensures the char after is NOT a word character


p1 = r"\^(\w{0,4})|(?<!\w)[^\w\s](?!\w)"

df['semiclean'] = df['semiclean'].apply(lambda x: re.sub(p1, "", x))
df['semiclean']
# Out:
# 0         i Class) $1.00      (2    thai  .r.Hpnry  Sm...
# 1        laa-Ji          Bryb &lt; jg  I   l-O:  f  \s...
# 2       e-   3    m                     pirn  }ZT:  &l...
# 3       top  qqu\ UJachdsooih     l     -fLtuLojr   CA...
# 4       p I  rlyAjxJi CUx Uaama   .fat, H CwMvvu.  PVL...
#                               ...
# 3379    September 25, 1946    ?R!V3 Newspaper Syndicat...
# 3380    September 27, W46    fthelyn  Psxkex  163a Lin...
# 3381    Sept. 28, 1946      J. Cling     583 King St. ...
# 3382    loja Line, St.    Charleston, S.C    Sept. 30,...
# 3383    1. I. Bash    Dalle's B. Salon    Conaway Drug...
# Name: semiclean, Length: 3384, dtype: object

# %%
# Remove ( and connected letter/word if there is no closing bracket
p2 = r'\([^)]*$'

df['semiclean'] = df['semiclean'].apply(lambda x: re.sub(p2, "", x))
df['semiclean']
# Out:
# 0                                    i Class) $1.00
# 1        laa-Ji          Bryb &lt; jg  I   l-O:  f  \s...
# 2       e-   3    m                     pirn  }ZT:  &l...
# 3       top  qqu\ UJachdsooih     l     -fLtuLojr   CA...
# 4       p I  rlyAjxJi CUx Uaama   .fat, H CwMvvu.  PVL...
#                               ...
# 3379    September 25, 1946    ?R!V3 Newspaper Syndicat...
# 3380    September 27, W46    fthelyn  Psxkex  163a Lin...
# 3381    Sept. 28, 1946      J. Cling     583 King St. ...
# 3382    loja Line, St.    Charleston, S.C    Sept. 30,...
# 3383    1. I. Bash    Dalle's B. Salon    Conaway Drug...
# Name: semiclean, Length: 3384, dtype: object

# %%
# Clean spacing (with auto newlining)

def normalize_spaces(text):
    return re.sub(r" {2,}", lambda m: "\n" if len(m.group(0)) > 3 else " ", text)

df['semiclean'] = df['semiclean'].apply(normalize_spaces)
df['semiclean']
# Out:
# 0                                        i Class) $1.00\n
# 1        laa-Ji\nBryb &lt; jg I l-O: f \s\tf\jhL taw c...
# 2       e- 3\nm\npirn }ZT: &lt;\n'as\nSTL\ny\nCuaiup y...
# 3       top qqu\ UJachdsooih\nl\n-fLtuLojr CAjjtLcm A4...
# 4       p I rlyAjxJi CUx Uaama .fat, H CwMvvu. PVLtTL ...
#                               ...
# 3379    September 25, 1946\n?R!V3 Newspaper Syndicate ...
# 3380    September 27, W46\nfthelyn Psxkex 163a Line St...
# 3381    Sept. 28, 1946\nJ. Cling\n583 King St.\nCharle...
# 3382    loja Line, St.\nCharleston, S.C\nSept. 30,1946...
# 3383    1. I. Bash\nDalle's B. Salon\nConaway Drugs\nO...
# Name: semiclean, Length: 3384, dtype: object

# %%
# Save
df.to_excel(Paths.mccray_folder + r'changed_data/decade_subsets/McCray (1940s, semi-cleaned).xlsx', index=0)
