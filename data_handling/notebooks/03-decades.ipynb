# %% [markdown]
# # Decade Seperation

# %%
import pandas as pd
import re, math
from utils.constants import Paths

# %%
# Load excel that had rows w/o transcrips pulled out
print(Paths.mccray_with_trscp)
df = pd.read_excel(Paths.mccray_with_trscp)
print(list(df))
df
# Out:
# ../../data/mccray/changed_data/trscp_subsets/McCray (with transcripts).xlsx
# ['Title', 'Creator', 'Contributors', 'Date', 'Approximate Date', 'Source', 'Subject', 'Local Subject', 'S.C. County', 'Description', 'Extent', 'Digital Collection', 'Website', 'Contributing Institution', 'Rights', 'Time Period', 'Geographic Location', 'Language', 'Digitization Specifications', 'Date Digital', 'Type', 'Format', 'Media Type', 'Identifier', 'Note', 'Digital Assistant', 'Transcript', 'OCLC number', 'Date created', 'Date modified', 'Reference URL', 'CONTENTdm number', 'CONTENTdm file name', 'CONTENTdm file path', 'Year', 'messy_sequences', 'messy_count', 'has_messy', 'total_messy_chars']
#                                                    Title  \
# 0      Afro-American Newsboy Application signed by Mr...
# 1                            Lighthouse Informer receipt
# 2      The Lighthouse Solicitor's Record, Home Office...
# 3              The Lighthouse Remittance Envelope(Front)
# 4      Advertisment, Chicken Special at the Pig Trail...
# ...                                                  ...
# 14140  Letter from Mildred Chestnut, Secretary at the...
# 14141  Letter from John H. McCray to Mr. Arthur W. Ai...
# 14142  Letter from John H. McCray to Dr. E. J. Cling,...
# 14143  Letter from Mrs. E.M. Parker to Mildred Chestn...
# 14144  List of Charleston's Advertising accounts for ...
#
#                                                  Creator  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14140  Chestnut, Mildred (Secretary for Lighthouse an...
# 14141                      McCray, John Henry, 1910-1987
# 14142                      McCray, John Henry, 1910-1987
# 14143                      McCray, John Henry, 1910-1987
# 14144                                                NaN
#
#                         Contributors                 Date Approximate Date  \
# 0      McCray, John Henry, 1910-1987                  NaN              NaN
# 1      McCray, John Henry, 1910-1987                  NaN              NaN
# 2      McCray, John Henry, 1910-1987                  NaN              NaN
# 3      McCray, John Henry, 1910-1987                  NaN              NaN
# 4      McCray, John Henry, 1910-1987                  NaN              NaN
# ...                              ...                  ...              ...
# 14140  McCray, John Henry, 1910-1987  1946-09-27 00:00:00              NaN
# 14141  McCray, John Henry, 1910-1987  1946-09-28 00:00:00              NaN
# 14142  McCray, John Henry, 1910-1987  1946-09-28 00:00:00              NaN
# 14143  McCray, John Henry, 1910-1987  1946-09-30 00:00:00              NaN
# 14144  McCray, John Henry, 1910-1987              1946-08              NaN
#
#                               Source                  Subject Local Subject  \
# 0      Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
# 1      Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
# 2      Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
# 3      Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
# 4      Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
# ...                              ...                      ...           ...
# 14140  Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
# 14141  Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
# 14142  Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
# 14143  Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
# 14144  Manuscripts; Accession 11294.  Lighthouse and Informer           NaN
#
#       S.C. County                                        Description  ...  \
# 0             NaN  An application to be a Newsboy for the Afro-Am...  ...
# 1             NaN           A blank Lighthouse and Informer receipt.  ...
# 2             NaN  A solicitor's record, home office order, and s...  ...
# 3             NaN     The front of a Lighthouse remittance envelope.  ...
# 4             NaN  An ad about the Chicken Special for the Pig Tr...  ...
# ...           ...                                                ...  ...
# 14140         NaN  Letter from Mildred Chestnut, Secretary at the...  ...
# 14141         NaN  Letter from John H. McCray to Mr. Arthur W. Ai...  ...
# 14142         NaN  Letter from John H. McCray to Dr. E. J. Cling ...  ...
# 14143         NaN  Letter from Mrs. E.M. Parker to Mildred Chestn...  ...
# 14144         NaN  List of Charleston's Advertising accounts for ...  ...
#
#       Date modified                                      Reference URL  \
# 0        2020-10-22  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 1        2020-10-22  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 2        2020-10-22  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 3        2020-10-22  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 4        2020-10-22  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# ...             ...                                                ...
# 14140    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 14141    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 14142    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 14143    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 14144    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
#
#       CONTENTdm number CONTENTdm file name            CONTENTdm file path  \
# 0                  0.0               1.jp2      /p17173coll38/image/1.jp2
# 1                  1.0               2.jp2      /p17173coll38/image/2.jp2
# 2                  2.0               3.jp2      /p17173coll38/image/3.jp2
# 3                  4.0               5.jp2      /p17173coll38/image/5.jp2
# 4                  5.0               6.jp2      /p17173coll38/image/6.jp2
# ...                ...                 ...                            ...
# 14140          20000.0           24801.jp2  /p17173coll38/image/24801.jp2
# 14141          20001.0           24802.jp2  /p17173coll38/image/24802.jp2
# 14142          20002.0           24803.jp2  /p17173coll38/image/24803.jp2
# 14143          20003.0           24804.jp2  /p17173coll38/image/24804.jp2
# 14144          20004.0           24805.jp2  /p17173coll38/image/24805.jp2
#
#          Year                      messy_sequences messy_count has_messy  \
# 0         NaN                                   []           0     False
# 1         NaN                                   []           0     False
# 2         NaN                                   []           0     False
# 3         NaN                                   []           0     False
# 4         NaN                                   []           0     False
# ...       ...                                  ...         ...       ...
# 14140  1946.0                               ['┬Ñ']           1      True
# 14141  1946.0                                   []           0     False
# 14142  1946.0  ['┬ú', 'ΓÇó', '┬úΓÇó', 'ΓÇó', '┬½']           5      True
# 14143  1946.0                              ['ΓÇÖ']           1      True
# 14144  1946.0                ['ΓÇÖ', 'ΓÇÖ', 'ΓÇÖ']           3      True
#
#       total_messy_chars
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 14140                 2
# 14141                 0
# 14142                15
# 14143                 3
# 14144                 9
#
# [14145 rows x 39 columns]

# %%
# Isolate the data given a specific range of years
start_year = 1941
end_year = 1950

df_1940s = df[df['Year'] != ""].copy() 
df_1940s['Year'] = df_1940s['Year'].apply(lambda x: 0 if math.isnan(x) else int(x))
df_1940s = df_1940s[df_1940s['Year'] >= start_year]
df_1940s = df_1940s[df_1940s['Year'] <= end_year]
df_1940s
# Out:
#                                                    Title  \
# 720    Certificate that Mr. Henry Smith is a member o...
# 735    The Lighthouse and Informer paper notes, Octob...
# 736    The Lighthouse and Informer paper notes, Octob...
# 738      2020-05-22  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# ...             ...                                                ...
# 14140    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 14141    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 14142    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 14143    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
# 14144    2022-09-16  http://cdm17173.contentdm.oclc.org/cdm/ref/col...
#
#       CONTENTdm number CONTENTdm file name            CONTENTdm file path  \
# 720              981.0             982.jp2    /p17173coll38/image/982.jp2
# 735              998.0             999.jp2    /p17173coll38/image/999.jp2
# 736              999.0            1000.jp2   /p17173coll38/image/1000.jp2
# 737             1000.0            1001.jp2   /p17173coll38/image/1001.jp2
# 738             1001.0            1002.jp2   /p17173coll38/image/1002.jp2
# ...                ...                 ...                            ...
# 14140          20000.0           24801.jp2  /p17173coll38/image/24801.jp2
# 14141          20001.0           24802.jp2  /p17173coll38/image/24802.jp2
# 14142          20002.0           24803.jp2  /p17173coll38/image/24803.jp2
# 14143          20003.0           24804.jp2  /p17173coll38/image/24804.jp2
# 14144          20004.0           24805.jp2  /p17173coll38/image/24805.jp2
#
#        Year                      messy_sequences messy_count has_messy  \
# 720    1942                ['ΓÇó', '┬╗', '┬╗┬╗']           3      True
# 735    1941             ['┬ú', '┬ú', '┬ú', '┬ú']           4      True
# 736    1941                         ['┬ú', '┬ú']           2      True
# 737    1944           ['┬░', '┬ú', 'Γûá', 'Γûá']           4      True
# 738    1944            ['Γûá', '┬ú', '┬ú', '┬ú']           4      True
# ...     ...                                  ...         ...       ...
# 14140  1946                               ['┬Ñ']           1      True
# 14141  1946                                   []           0     False
# 14142  1946  ['┬ú', 'ΓÇó', '┬úΓÇó', 'ΓÇó', '┬½']           5      True
# 14143  1946                              ['ΓÇÖ']           1      True
# 14144  1946                ['ΓÇÖ', 'ΓÇÖ', 'ΓÇÖ']           3      True
#
#       total_messy_chars
# 720                   9
# 735                   8
# 736                   4
# 737                  10
# 738                   9
# ...                 ...
# 14140                 2
# 14141                 0
# 14142                15
# 14143                 3
# 14144                 9
#
# [3958 rows x 39 columns]

# %%
# Save and print trscps
df_1940s.to_excel(Paths.mccray_1940s_subset)
df_1940s['Transcript']
# Out:
# 720      $i&S&lt;Z&rJk  i Class) $1.00      (2  (El|ie ...
# 735      \J^AAyuAJ- ┬úlaa-Ji  -     C$UZ^lt?terV) -  Br...
# 736      e-  \ 3 "  ^ m  1^7^  &lpJ&gt;   Ct^UL ~    & ...
# 737      top ." qqu\ UJachdsooih  2)&u?vi   l^~ G&rmfrv...
# 738      p I  rlyAjxJi CUx Uaama^ ^ Clx^ilwterv) *-.fat...
#                                ...
# 14140    September 27, W46    fthelyn ┬Ñ. Psxkex  163a ...
# 14141    Sept. 28, 1946    MX* Ait hoi W* Aiken    429 ...
# 14142    Sept. 28, 1946    ┬ú&ΓÇó ┬úΓÇó J. Cling \    5...
# 14143    loja Line, St.,    Charleston, S.C    Sept. 30...
# 14144    1. I. Bash    Dalle's B. Salon    Conaway Drug...
# Name: Transcript, Length: 3958, dtype: object

# %%
# remove messy_char != 0 and save
df_1940_cleanish = df_1940s[df_1940s['messy_count'] == 0]
df_1940_cleanish.to_excel(Paths.mccray_1940s_cleaner)
